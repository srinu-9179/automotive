# %% [markdown]
# <a href="https://colab.research.google.com/github/srinu-9179/automotive/blob/main/helmet_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/meryemsakin/helmet-detection-yolov8.git
# Out:
# Cloning into 'helmet-detection-yolov8'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 93 (delta 27), reused 5 (delta 1), pack-reused 43 (from 1)
# Receiving objects: 100% (93/93), 60.35 MiB | 17.12 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# Updating files: 100% (28/28), done.
